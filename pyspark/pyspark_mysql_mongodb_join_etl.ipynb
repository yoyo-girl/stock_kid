# %% [markdown]
# # 載入 sqlContext 函式庫
# ## 抓取 Mongodb 資料，例如: 2019063020 (YYYYMMDDHH)

# %%
from pyspark.sql import SQLContext, SparkSession
from pyspark import SparkContext, SparkConf

sparkConf = SparkConf().setMaster("local") \
            .setAppName("mysql-mongodb-etl") 
            
sc = SparkContext(conf=sparkConf)
sqlContext = SQLContext(sc)

# %% [markdown]
# # 設定遠端 Mongodb 連線資訊
# ## 修改抓資料日期

# %%
#data_2019063020
#data_2019063021
df_mongo = sqlContext.read.format("com.mongodb.spark.sql.DefaultSource")\
                     .option("spark.mongodb.input.uri", "mongodb://mongodb:27017/ltu_demo.data_2019063020").load()

# %% [markdown]
# # 試試看，是否有資料

# %%
df_mongo.first()
# Out:
# Row(Humidity=66, Temperature=27.0, _id=Row(oid='5d1b8d40be567be7cc90353b'), device_id='001', timestamp='2019-07-03 00:37:12')

# %% [markdown]
# # 設定遠端 Mysql 連線資訊

# %%
df_mysql=sqlContext.read.format("jdbc").options(url="jdbc:mysql://mysql:3306/ltu",
                                             driver="com.mysql.jdbc.Driver",
                                             dbtable="(SELECT * FROM device) tmp",user="root",
                                             password="iii").load()

# %% [markdown]
# # 試試看，是否有資料

# %%
df_mysql.show()
# Out:
# +---------+--------+--------------------+
# |device_id|location|         description|
# +---------+--------+--------------------+
# |      001|Taichung|Semiconductor-Mac...|
# |      002|Taichung|Semiconductor-Mac...|
# |      003|Taichung|Semiconductor-Mac...|
# |      004|Taichung|Semiconductor-Mac...|
# |      005|Taichung|Semiconductor-Mac...|
# +---------+--------+--------------------+

# %% [markdown]
# # 將 SQLContext 轉成 pandas 資料格式
# ## 因為我們希望透過 pandas 幫忙 merge 兩個資料集

# %%
pandas_mysql=df_mysql.toPandas()
pandas_mongo=df_mongo.toPandas()

# %% [markdown]
# # merge 兩個資料集
# ## 以 device_id 合併

# %%
import pandas as pd

pandas_result = pd.merge(pandas_mysql, pandas_mongo, on=['device_id'])

# %% [markdown]
# # 查看 merge 之後的結果

# %%
pandas_result
# Out:
#     device_id  location               description  Humidity  Temperature  \
# 0         001  Taichung  Semiconductor-Machine-01        66         27.0
# 1         001  Taichung  Semiconductor-Machine-01        66         27.0
# 2         001  Taichung  Semiconductor-Machine-01        64         27.0
# 3         001  Taichung  Semiconductor-Machine-01        64         27.0
# 4         001  Taichung  Semiconductor-Machine-01        64         27.0
# 5         001  Taichung  Semiconductor-Machine-01        63         27.0
# 6         001  Taichung  Semiconductor-Machine-01        64         27.0
# 7         001  Taichung  Semiconductor-Machine-01        65         27.0
# 8         001  Taichung  Semiconductor-Machine-01        65         27.0
# 9         001  Taichung  Semiconductor-Machine-01        67         27.0
# 10        001  Taichung  Semiconductor-Machine-01        67         27.0
# 11        001  Taichung  Semiconductor-Machine-01        67         27.0
# 12        001  Taichung  Semiconductor-Machine-01        66         27.0
# 13        001  Taichung  Semiconductor-Machine-01        66         27.0
# 160  (5d1b8e11be567be7cc9035db,)  2019-07-03 01:02:09
# 161  (5d1b8e16be567be7cc9035dc,)  2019-07-03 01:02:14
# 162  (5d1b8e1cbe567be7cc9035dd,)  2019-07-03 01:02:19
# 163  (5d1b8e2bbe567be7cc9035de,)  2019-07-03 01:02:35
# 164  (5d1b8e3abe567be7cc9035df,)  2019-07-03 01:02:50
# 165  (5d1b8e4abe567be7cc9035e0,)  2019-07-03 01:03:05
# 166  (5d1b8e54be567be7cc9035e1,)  2019-07-03 01:03:16
# 167  (5d1b8e5ebe567be7cc9035e2,)  2019-07-03 01:03:26
# 168  (5d1b8e63be567be7cc9035e3,)  2019-07-03 01:03:31
# 169  (5d1b8e68be567be7cc9035e4,)  2019-07-03 01:03:36
# 170  (5d1b8e6ebe567be7cc9035e5,)  2019-07-03 01:03:41
# 171  (5d1b8e73be567be7cc9035e6,)  2019-07-03 01:03:47
# 172  (5d1b8e78be567be7cc9035e7,)  2019-07-03 01:03:52
# 173  (5d1b8e7dbe567be7cc9035e8,)  2019-07-03 01:03:57
# 174  (5d1b8e82be567be7cc9035e9,)  2019-07-03 01:04:02
# 175  (5d1b8e87be567be7cc9035ea,)  2019-07-03 01:04:07
# 176  (5d1b8e8dbe567be7cc9035eb,)  2019-07-03 01:04:12
# 177  (5d1b8e92be567be7cc9035ec,)  2019-07-03 01:04:17
# 178  (5d1b8e9cbe567be7cc9035ed,)  2019-07-03 01:04:28
#
# [179 rows x 7 columns]

# %% [markdown]
# # 將 pandas 轉回 SQLContext
# ## 因為我們要透過 SQLContext 回寫 Mongodb

# %%
sqlContext = SQLContext(sc)
df_result = sqlContext.createDataFrame(pandas_result)

# %% [markdown]
# # 查看經過整合資後的資料樣貌

# %%
df_result.show()
# Out:
# +---------+--------+--------------------+--------+-----------+--------------------+-------------------+
# |device_id|location|         description|Humidity|Temperature|                 _id|          timestamp|
# +---------+--------+--------------------+--------+-----------+--------------------+-------------------+
# |      001|Taichung|Semiconductor-Mac...|      66|       27.0|[5d1b8d40be567be7...|2019-07-03 00:37:12|
# |      001|Taichung|Semiconductor-Mac...|      66|       27.0|[5d1b8d40be567be7...|2019-07-03 00:41:30|
# |      001|Taichung|Semiconductor-Mac...|      64|       27.0|[5d1b8d40be567be7...|2019-07-03 00:42:47|
# |      001|Taichung|Semiconductor-Mac...|      64|       27.0|[5d1b8d40be567be7...|2019-07-03 00:44:49|
# |      001|Taichung|Semiconductor-Mac...|      64|       27.0|[5d1b8d40be567be7...|2019-07-03 00:45:10|
# |      001|Taichung|Semiconductor-Mac...|      63|       27.0|[5d1b8d40be567be7...|2019-07-03 00:45:51|
# |      001|Taichung|Semiconductor-Mac...|      64|       27.0|[5d1b8d40be567be7...|2019-07-03 00:46:43|
# |      001|Taichung|Semiconductor-Mac...|      65|       27.0|[5d1b8d40be567be7...|2019-07-03 00:47:24|
# |      001|Taichung|Semiconductor-Mac...|      65|       27.0|[5d1b8d40be567be7...|2019-07-03 00:47:35|
# |      001|Taichung|Semiconductor-Mac...|      67|       27.0|[5d1b8d40be567be7...|2019-07-03 00:48:42|
# |      001|Taichung|Semiconductor-Mac...|      67|       27.0|[5d1b8d40be567be7...|2019-07-03 00:49:13|
# |      001|Taichung|Semiconductor-Mac...|      67|       27.0|[5d1b8d40be567be7...|2019-07-03 00:49:23|
# |      001|Taichung|Semiconductor-Mac...|      66|       27.0|[5d1b8d40be567be7...|2019-07-03 00:49:38|
# |      001|Taichung|Semiconductor-Mac...|      66|       27.0|[5d1b8d40be567be7...|2019-07-03 00:49:43|
# |      001|Taichung|Semiconductor-Mac...|      66|       27.0|[5d1b8d40be567be7...|2019-07-03 00:50:40|
# |      001|Taichung|Semiconductor-Mac...|      65|       27.0|[5d1b8d40be567be7...|2019-07-03 00:51:26|
# |      001|Taichung|Semiconductor-Mac...|      65|       27.0|[5d1b8d40be567be7...|2019-07-03 00:52:28|
# |      001|Taichung|Semiconductor-Mac...|      65|       27.0|[5d1b8d40be567be7...|2019-07-03 00:52:33|
# |      001|Taichung|Semiconductor-Mac...|      65|       27.0|[5d1b8d40be567be7...|2019-07-03 00:52:38|
# |      001|Taichung|Semiconductor-Mac...|      65|       27.0|[5d1b8d40be567be7...|2019-07-03 00:52:49|
# +---------+--------+--------------------+--------+-----------+--------------------+-------------------+
# only showing top 20 rows

# %% [markdown]
# # 查看 timestamp 資料

# %%
df_result.select("timestamp").show()
# Out:
# +-------------------+
# |          timestamp|
# +-------------------+
# |2019-07-03 00:37:12|
# |2019-07-03 00:41:30|
# |2019-07-03 00:42:47|
# |2019-07-03 00:44:49|
# |2019-07-03 00:45:10|
# |2019-07-03 00:45:51|
# |2019-07-03 00:46:43|
# |2019-07-03 00:47:24|
# |2019-07-03 00:47:35|
# |2019-07-03 00:48:42|
# |2019-07-03 00:49:13|
# |2019-07-03 00:49:23|
# |2019-07-03 00:49:38|
# |2019-07-03 00:49:43|
# |2019-07-03 00:50:40|
# |2019-07-03 00:51:26|
# |2019-07-03 00:52:28|
# |2019-07-03 00:52:33|
# |2019-07-03 00:52:38|
# |2019-07-03 00:52:49|
# +-------------------+
# only showing top 20 rows

# %% [markdown]
# # 查看 humidity 資料

# %%
df_result.select("humidity").show()
# Out:
# +--------+
# |humidity|
# +--------+
# |      66|
# |      66|
# |      64|
# |      64|
# |      64|
# |      63|
# |      64|
# |      65|
# |      65|
# |      67|
# |      67|
# |      67|
# |      66|
# |      66|
# |      66|
# |      65|
# |      65|
# |      65|
# |      65|
# |      65|
# +--------+
# only showing top 20 rows

# %% [markdown]
# # 寫入 Mongodb，寫入位置: ltu-demo.final
# ## 覆蓋到原有資料: mode("overwrite")

# %%
df_result.write.format("com.mongodb.spark.sql.DefaultSource")\
                    .option("spark.mongodb.output.uri", "mongodb://mongodb:27017/ltu_demo.final")\
                    .mode("append")\
                    .save()

# %%
sc.stop()
